# %%
import sys
import warnings  # `do not disturbe` mode
warnings.filterwarnings('ignore')
from tqdm import tqdm, tqdm_notebook
from itertools import product

# %%
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta # work with dates with style
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error 
from sklearn.metrics import mean_squared_error, mean_squared_log_error

# %%
import statsmodels.formula.api as smf # statistics and econometrics
import statsmodels.tsa.api as smt
import statsmodels.api as sm

# %%
import scipy.stats as scs
from scipy.optimize import minimize

# %%
from arch import arch_model

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# nahren ploty

# %%
1-4

# %%
online_df = pd.read_csv('../Data/hour_online.csv', index_col=['Time'], parse_dates=['Time'])
ads_df = pd.read_csv('../Data/ads.csv', index_col=['Time'], parse_dates=['Time'])
curr_df = pd.read_csv('../Data/currency.csv', index_col=['Time'], parse_dates=['Time'])

# %%
plt.plot?

# %%
plt.figure(figsize=(15,7))
plt.plot(dataset)
plt.title('Online users')
plt.grid(True)
pplt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-2161cf4683d7> in <module>
#       3 plt.title('Online users')
#       4 plt.grid(True)
# ----> 5 pplt.show()
#
# NameError: name 'pplt' is not defined

# %%
#plt.show?

# %%
def moving_average(series, n):
    est_mv_av = np.average(series[-n:])
    return est_mv_av

# %%
moving_average(online_df.Users, 24)
# Out:
# 29858.333333333332

# %%
moving_average(curr_df, 72)
# Out:
# 1807987.5833333333

# %%
moving_average(ads_df, 10)
# Out:
# 130621.5

# %%
#dataset.Users?

# %%
#plt.figure?

# %%
online_df.Users.rolling(window=72).mean().tail()
# Out:
# Time
# 2017-04-20 05:00:00    31649.194444
# 2017-04-20 06:00:00    31589.138889
# 2017-04-20 07:00:00    31535.888889
# 2017-04-20 08:00:00    31482.458333
# 2017-04-20 09:00:00    31428.777778
# Name: Users, dtype: float64

# %%
rolling_mean = online_df.rolling(window=72).mean()
rolling_mean.head(), rolling_mean.tail()
# Out:
# (                     Users
#  Time
#  2017-01-01 00:00:00    NaN
#  2017-01-01 01:00:00    NaN
#  2017-01-01 02:00:00    NaN
#  2017-01-01 03:00:00    NaN
#  2017-01-01 04:00:00    NaN,                             Users
#  Time
#  2017-04-20 05:00:00  31649.194444
#  2017-04-20 06:00:00  31589.138889
#  2017-04-20 07:00:00  31535.888889
#  2017-04-20 08:00:00  31482.458333
#  2017-04-20 09:00:00  31428.777778)

# %%
mae = mean_absolute_error(online_df[72:], rolling_mean[72:])
mae
# Out:
# 9937.96328393611

# %%
deviation = np.std(online_df[72:] - rolling_mean[72:]) #sigma
deviation
# Out:
# Users    11712.88814
# dtype: float64

# %%
np.std?

# %%
len(online_df.Users[72:])
# Out:
# 2553

# %%
len(online_df.Users)
# Out:
# 2625

# %%
sum = 0
new = online_df.Users[72:].values - rolling_mean.Users[72:].values
print(new)
new_mean = np.mean(new)
print(new_mean)
for i, j in enumerate(new):
    sum += (j-new_mean) ** 2

np.sqrt(sum /len(new))
# Out:
# [-9464.68055556 -4993.58333333 -2521.16666667 ...  6882.11111111
#   8755.54166667  9334.22222222]
# -165.68046851199028
# 11712.88814012592

# %%
np.power?

# %%
sum = 0
mean_test = np.mean(online_df[72:] - rolling_mean[72:])
for i in range(72, len(online_df.Users)):
    sum += np.abs(online_df.Users.iloc[i] - rolling_mean.Users.iloc[i])

(sum/len(online_df[72:]))
# Out:
# 9937.96328393613

# %%
sum = 0
mean_test = np.mean(online_df[72:] - rolling_mean[72:])
for i in range(72, len(online_df.Users)):
    sum += np.abs(online_df.Users.iloc[i] - rolling_mean.Users.iloc[i])

(sum/len(online_df[72:]))
# Out:
# 9937.96328393613

# %%
online_df.Users[72:].values, rolling_mean.Users[72:].values
# Out:
# (array([34179, 38660, 41127, ..., 38418, 40238, 40763], dtype=int64),
#  array([43643.68055556, 43653.58333333, 43648.16666667, ...,
#         31535.88888889, 31482.45833333, 31428.77777778]))

# %%
i = 1
i +=1
i
# Out:
# 2

# %%
np.std?

# %%
def plotMovingAverage(series, window, plot_intervals=False, scale=1.96, plot_anomalies=False):
    '''
    series - dataframe with timeseries
    window - rolling window size
    plot_intervals - show confidence intervals
    plot_anomalies - show anomalies
    '''
    rolling_mean = series.rolling(window=window).mean() #method for creating average mean (or not mean)
    
    plt.figure(figsize=(15,5))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, "r", label='Rolling mean trend')
    
    
    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale*deviation)
        upper_bond = rolling_mean + (mae + scale*deviation)
        plt.plot(upper_bond, 'g--', label='Upper bond/ lower bond')
        plt.plot(lower_bond, 'g--')
    
    # Having the intervals, find abnormal values
    if plot_anomalies:
        anomalies = pd.DataFrame(index=series.index, columns=series.columns)
        anomalies[series<lower_bond] = series[series<lower_bond]
        anomalies[series>upper_bond] = series[series>upper_bond]
        plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='upper left')

# %%
plotMovingAverage(online_df, 24, plot_intervals=True, plot_anomalies=True)

# %%
plotMovingAverage(curr_df, 24, plot_intervals=True, plot_anomalies=True)

# %%
plotMovingAverage(ads_df, 12)

# %%
def weight_average(series, weights):
    '''
    calculate weighter average on series
    '''
    w_a = 0.0
    for n in range(len(weights)):
        w_a += series.iloc[-n-1].values*weights[-n-1]
    return float(w_a)

# %%
weight_average(ads_df, [0.6, 0.3, 0.1])
# Out:
# 98423.0

# %%
weight_average(online_df, [0.6, 0.2, 0.1, 0.07, 0.03])
# Out:
# 35967.55
