# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('../Data/hour_online.csv')
a.head()
# Out:
#           Time  Users
# 0  1/1/17 0:00  34002
# 1  1/1/17 1:00  37947
# 2  1/1/17 2:00  41517
# 3  1/1/17 3:00  44476
# 4  1/1/17 4:00  46234

# %%
plt.plot(a['Time'][:1000], a['Users'][:1000]);

# %%
plt.plot?
